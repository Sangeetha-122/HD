# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha-122/HD/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTHON is a interpreted language with a bytecode layer
#
# platform independent
#
# easier debugging as errors

# %% [markdown]
# # **Tokens in python**

# %% [markdown]
# # **Tokens**
#   keywords
#
#   identifiers
#
#   literals
#
#   delimiters
#
#   operators

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # **Operators**

# %% [markdown]
# **Arithmetic operators**

# %% [markdown]
#  + addition, - subtracton ,*multiplaction, /division,//floor division,**exponential,%reminder

# %%
5+5
# Out:
# 10

# %%
5-2
# Out:
# 3

# %%
2*3
# Out:
# 6

# %%
2/2
# Out:
# 1.0

# %%
11//3
# Out:
# 3

# %%
5%2
# Out:
# 1

# %%
3**2
# Out:
# 9

# %% [markdown]
# # **Bitwise operators**

# %% [markdown]
# &AND, |OR, ~NOT, ^XOR, <<LEFT SHIFT,>>RIGHT SHIFT

# %%
10&3
# Out:
# 2

# %%
10|3
# Out:
# 11

# %%
10^3
# Out:
# 9

# %%
~10
# Out:
# -11

# %%
10<<3H
# Out:
# 80

# %%
10>>3
# Out:
# 1

# %% [markdown]
# **Assignment operator**

# %% [markdown]
# > we can do both arithmetic and bitwise operators in assignment operators

# %%
a=3
a
# Out:
# 3

# %%
a+=3
a
# Out:
# 6

# %%
a-=3
a
# Out:
# 3

# %%
a*=3
a
# Out:
# 9

# %%
a/=3
a
# Out:
# 3.0

# %%
a//=3
a
# Out:
# 1.0

# %%
a=3
a**=3
a
# Out:
# 27

# %%
a =10
b=4
a&b
# Out:
# 0

# %%
a|b
# Out:
# 14

# %%
a^b
# Out:
# 14

# %%
a<<3
# Out:
# 80

# %% [markdown]
# **Comparision operator**

# %%
10 ==10
# Out:
# True

# %%
10==3
# Out:
# False

# %%
1!=3
# Out:
# True

# %%
10>3
# Out:
# True

# %%
10<3
# Out:
# False

# %%
10>10
# Out:
# False

# %%
10>=10
# Out:
# True

# %%
10<=3
# Out:
# False

# %% [markdown]
# **Logical operator**

# %% [markdown]
# and, or ,not

# %%
10>3 and 10<3
# Out:
# False

# %%
10>3 or 10<3
# Out:
# True

# %%
not 10>3
# Out:
# False

# %% [markdown]
# # **Data types in python**

# %% [markdown]
# **TYPE CHECKING**

# %%
type(3)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type(10+3j)
# Out:
# complex

# %%
type(3e-4)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
type(True)
# Out:
# bool
